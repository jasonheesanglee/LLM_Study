# %% [markdown]
# <a href="https://colab.research.google.com/github/jasonheesanglee/LLM_Study/blob/main/Retrieval.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Document Loaders

# %%
# !pip install -qqq fastapi kaleido uvicorn
# !pip install -qqq langchain unstructured pypdf pdf2image docx2txt -U pdfminer.six
# !pip install -qqq pillow_heif
# !pip install -qqq unstructured-inference
# !pip install -qqq pikepdf
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.1/92.1 kB 2.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 10.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 6.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 7.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.4 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires python-multipart, which is not installed.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 811.8/811.8 kB 6.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 12.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.0/284.0 kB 13.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from langchain.document_loaders import WebBaseLoader
loader = WebBaseLoader('https://n.news.naver.com/mnews/article/092/0002307222?sid=105')

# %%
data= loader.load()
print(data[0].page_content)

# %%
data[0]
# Out:
# Document(page_content='\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"AI, 5년 뒤 사람보다 더 똑똑해진다"\n\n\n\n\n\n\n\n\n\n\n\n\n\n본문 바로가기\n\n\n\n\n\n\nNAVER\n\n뉴스\n\n\n연예\n\n\n\n\n스포츠\n\n\n\n\n날씨\n\n\n\n\n프리미엄\n\n\n\n\n\n\n\n\n\n\n검색\n\n\n\n\n\n\n\n\n\n\n언론사별\n\n\n정치\n\n\n경제\n\n\n사회\n\n\n생활/문화\n\n\nIT/과학\n\n\n세계\n\n\n랭킹\n\n\n신문보기\n\n\n오피니언\n\n\nTV\n\n\n팩트체크\n\n\n알고리즘 안내\n\n\n정정보도 모음\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n구독\n\n지디넷코리아 언론사 구독되었습니다. 메인 뉴스판에서  주요뉴스를  볼 수 있습니다.\n보러가기\n\n\n지디넷코리아 언론사 구독 해지되었습니다.\n\n\n\n\nPICK\n안내\n\n\n언론사가 주요기사로선정한 기사입니다.\n언론사별 바로가기\n닫기\n\n\n\n\n"AI, 5년 뒤 사람보다 더 똑똑해진다"\n\n\n\n\n입력2023.10.09. 오후 12:27\n\n기사원문\n \n\n\n\n\n김미정 기자\n\nTALK\n\n\n\n\n\n\n\n\n\n김미정 기자\n\nTALK\n구독\n구독중\n\n\n\n\n구독자\n0\n\n\n응원수\n0\n\n\n\n더보기\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n추천\n\n\n\n\n쏠쏠정보\n0\n\n\n\n\n흥미진진\n0\n\n\n\n\n공감백배\n0\n\n\n\n\n분석탁월\n0\n\n\n\n\n후속강추\n0\n\n\n \n\n\n\n댓글\n\n\n\n\n\n본문 요약봇\n\n\n\n본문 요약봇도움말\n자동 추출 기술로 요약된 내용입니다. 요약 기술의 특성상 본문의 주요 내용이 제외될 수 있어, 전체 맥락을 이해하기 위해서는 기사 본문 전체보기를 권장합니다.\n닫기\
# ...

# %%
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 10.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 21.8 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# imageio 2.31.6 requires pillow<10.1.0,>=8.3.2, but you have pillow 10.2.0 which is incompatible.

# %%
from langchain.document_loaders import UnstructuredURLLoader
urls = ['https://n.news.naver.com/mnews/article/092/0002307222?sid=105',
        'https://n.news.naver.com/mnews/article/052/0001944792?sid=105'
        ]

loader = UnstructuredURLLoader(urls=urls)
data = loader.load()
data
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# ...

# %%
from langchain.document_loaders import PyPDFLoader

loader = PyPDFLoader('/content/drive/MyDrive/Colab Notebooks/DS트랙 강의자료_LLM/이론/T-12-01-04_Mixed Precision.pdf')
pages = loader.load_and_split()

# %%
for i in range(len(pages)):
    print(pages[i].page_content)
    print()
# Out:
# MIXED PRECISION TRAINING
# - paper explained ( Micikevicius  et al., 2018; ICLR)
# - PyTorch  tutorial ( torch.cuda.amp )
#
# MIXED PRECISION TRAINING
# Micikevicius et al., 2018; ICLR
# •Introduce three techniques  for training with FP16 while still matching the
# model accuracy of FP32 training session:
# 1.Single -precision master weights and updates
# 2.Loss scaling
# 3.Accumulating FP16 products into FP32
#
# MIXED PRECISION TRAINING
# How to represent a number in IEEE 754 floating point?
# Half precision FP16 0101110000011101
# 263.3 Single precision FP32 01000011100000111010011001100110
# Double precision FP64 0100000001110000011101001100110011001100110011001100110011001101sign (1 bit)
# exponent (5 bit)
# fraction (10 bit)
# sign (1 bit)
# exponent (8 bit)
# fraction (23 bit)
# sign (1 bit)
# exponent (11 bit)
# fraction (52 bit)-inf 0 inf
# 2−24−2−2465504 −65504
#
# MIXED PRECISION TRAINING
# FP32 Master copy of weights
# •Why do we maintain FP32 master copy of weights?
# ...

# %%
from langchain.document_loaders import Docx2txtLoader
loader = Docx2txtLoader('/content/drive/MyDrive/Copy of Switzerland Life.docx')
data = loader.load()
data[0].page_content
# Out:
# 'Hello guys, I’m Beijing Royal School 2015 graduate Jason Heesang LEE.\n\n\n\nAfter graduating from Beijing Royal School, I went to Switzerland for the next step studying. Actually, I was preparing to go to United States for university like everyone else did. However I felt that I’m following the trend, not following my dream. So I stopped preparing for United States, but started preparing for Switzerland. Everyone asked me “Why are you going to Switzerland? Let’s go to United States together.” Then I answered, “I found what I want to do, and I want to receive the best education for it.” As Switzerland is known for its hospitality education, it was my decision to go to the best school, Glion Institute of Higher Education.\n\n(0)\n\n\n\nBefore my story starts, I want to say one thing clearly to fellow students in BRS.\n\n\n\n“Follow your dream, not the trend.”\n\n\n\nI don’t mean, “Don’t go to United States.”\n\nUnited States is a great country, and lots of great universities are in U
# ...

# %%
data[0].metadata
# Out:
# {'source': '/content/drive/MyDrive/Copy of Switzerland Life.docx'}

# %%
from langchain.document_loaders.csv_loader import CSVLoader

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Avocado_Land/nouns.csv')
cols = df.columns
cols
# Out:
# Index(['original', 'preprocessing only', 'naver', 't5', 'pykospacing',
#        'gptservice', 'gptapi', 'original_noun_list', 'original_all_noun_list',
#        'preprocessing only_noun_list', 'preprocessing only_all_noun_list',
#        'naver_noun_list', 'naver_all_noun_list', 't5_noun_list',
#        't5_all_noun_list', 'pykospacing_noun_list',
#        'pykospacing_all_noun_list', 'gptservice_noun_list',
#        'gptservice_all_noun_list', 'gptapi_noun_list', 'gptapi_all_noun_list'],
#       dtype='object')

# %%
loader = CSVLoader(file_path='/content/drive/MyDrive/Colab Notebooks/Avocado_Land/nouns.csv',
                   csv_args={'delimiter':',',
                             'quotechar':'"',
                             'fieldnames':list(cols)})
data=loader.load()
data[:2]
# Out:
# [Document(page_content='original: original\npreprocessing only: preprocessing only\nnaver: naver\nt5: t5\npykospacing: pykospacing\ngptservice: gptservice\ngptapi: gptapi\noriginal_noun_list: original_noun_list\noriginal_all_noun_list: original_all_noun_list\npreprocessing only_noun_list: preprocessing only_noun_list\npreprocessing only_all_noun_list: preprocessing only_all_noun_list\nnaver_noun_list: naver_noun_list\nnaver_all_noun_list: naver_all_noun_list\nt5_noun_list: t5_noun_list\nt5_all_noun_list: t5_all_noun_list\npykospacing_noun_list: pykospacing_noun_list\npykospacing_all_noun_list: pykospacing_all_noun_list\ngptservice_noun_list: gptservice_noun_list\ngptservice_all_noun_list: gptservice_all_noun_list\ngptapi_noun_list: gptapi_noun_list\ngptapi_all_noun_list: gptapi_all_noun_list', metadata={'source': '/content/drive/MyDrive/Colab Notebooks/Avocado_Land/nouns.csv', 'row': 0}),
# ...

# %%
data[0].page_content
# Out:
# 'original: original\npreprocessing only: preprocessing only\nnaver: naver\nt5: t5\npykospacing: pykospacing\ngptservice: gptservice\ngptapi: gptapi\noriginal_noun_list: original_noun_list\noriginal_all_noun_list: original_all_noun_list\npreprocessing only_noun_list: preprocessing only_noun_list\npreprocessing only_all_noun_list: preprocessing only_all_noun_list\nnaver_noun_list: naver_noun_list\nnaver_all_noun_list: naver_all_noun_list\nt5_noun_list: t5_noun_list\nt5_all_noun_list: t5_all_noun_list\npykospacing_noun_list: pykospacing_noun_list\npykospacing_all_noun_list: pykospacing_all_noun_list\ngptservice_noun_list: gptservice_noun_list\ngptservice_all_noun_list: gptservice_all_noun_list\ngptapi_noun_list: gptapi_noun_list\ngptapi_all_noun_list: gptapi_all_noun_list'

# %%
data[1].page_content
# Out:
# "original: 오늘은 비가 와서 그런가 기분도 별로고, 컨디션도 별로 였슴다.\n프로젝트 하는데, 일단 이것저것 해보고 있긴한데, 생각보다 난이도가 높다고 느끼고 있네요.\n평소 생각을 정리할 때 자주 하던 산책을 하면서 생각을 해보고 있는데, 아 쉽지 않슴다.\n우리 task에 맞는 모델이나 알고리즘을 찾는건가 싶다가도, 세상에 없는 시스템을 만들고 있는건가 생각도 들고 그러네요. 쉽진 않아서 침울해졌다가도, 그래도 제대로 해내면 얼마나 멋있을까 하면서 마음을 다잡습니다.\n잘 되면 되게 뿌듯할 것 같네요. 오늘 저녁은 맛있는 걸로 먹어야겠습니다.\npreprocessing only: 오늘은 비가 와서 그런가 기분도 별로고 컨디션도 별로 였슴다 프로젝트 하는데 일단 이것저것 해보고 있긴한데 생각보다 난이도가 높다고 느끼고 있네요 평소 생각을 정리할 때 자주 하던 산책을 하면서 생각을 해보고 있는데 아 쉽지 않슴다 우리 task에 맞는 모델이나 알고리즘을 찾는건가 싶다가도 세상에 없는 시스템을 만들고 있는건가 생각도 들고 그러네요 쉽진 않아서 침울해졌다가도 그래도 제대로 해내면 얼마나 멋있을까 하면서 마음을 다잡습니다 잘 되면 되게 뿌듯할 것 같네요 오늘 저녁은 맛있는 걸로 먹어야겠습니다\nnaver: 오늘은 비가 와서 그런가 기분도 별로고 컨디션도 별로였습니다 프로젝트 하는데 일단 이것저것 해보고 있긴 한데 생각보다 난이도가 높다고 느끼고 있네요 평소 생각을 정리할 때 자주 하던 산책을 하면서 생각을 해보고 있는데 아 쉽지 않습니다 우리 task에 맞는 모델이나 알고리즘을 찾는 건가 싶다가도 세상에 없는 시스템을 만들고 있는 건가 생각도 들고 그러네요 쉽진 않아서 침울해졌다가도 그래도 제대로 해내면 얼마나 멋있을까 하면서 마음을 다잡습니다 잘 되면 되게 뿌듯할 것 같네요 오늘 저녁은 맛있는 걸로 먹어야겠습니다\nt5: 오늘은 비가 와서 그런가 기분도 별로고 컨디션도 별로였습니다.프로젝트 하는데 일단 이것저것 해 보고 있긴 한데 생각보다 난이도가 높다
# ...

# %% [markdown]
# # Text Splitters

# %% [markdown]
# Character Text Splitter

# %%
import zipfile
import os

zip_ref = zipfile.ZipFile('/content/drive/MyDrive/Colab Notebooks/dreaming/emotional_reading/gutenberg-over-70000.zip')
zip_ref.extract(member='1-500/100_TheCompleteWorks.pkl', path='/content/')
# Out:
# '/content/1-500/100_TheCompleteWorks.pkl'

# %%
import pickle
with open('/content/1-500/100_TheCompleteWorks.pkl', 'rb') as f:
    data = pickle.load(f)
print(data[:10])
with open('/content/sample_text.txt', 'w') as f:
    f.write(data)

with open('/content/sample_text.txt') as f:
    sample = f.read()
# Out:
# ﻿The Proje

# %%
sample[:20]
# Out:
# '\ufeffThe Project Gutenbe'

# %%
from langchain.text_splitter import CharacterTextSplitter

text_splitter = CharacterTextSplitter(
    separator='\n\n',
    chunk_size=1000,
    chunk_overlap=100,
    length_function=len,
)

# %%
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')

texts = text_splitter.split_text(sample)
print(texts[0])
print('-'*100)
print(texts[1])
print('-'*100)
print(texts[2])

# %%
char_list = []
for i in range(len(texts)):
    if len(texts[i]) > 1000:
        char_list.append(len(texts[i]))
print(char_list)
# Out:
# [1328, 1050, 1109, 1216, 1344, 1235, 1051, 1222, 1340, 1329, 1195, 1099, 2666, 1569, 1228, 1070, 1085, 1700, 1015, 1754, 1606, 1489, 1297, 1427, 1838, 1183, 1017, 1535, 1317, 1066, 1215, 1290, 1668, 1468, 1747, 1197, 1297, 1222, 1694, 1319, 1362, 1474, 1049, 1070, 2024, 1530, 1336, 2445, 1505, 1023, 1397, 1294, 1576, 1528, 1010, 1470, 1415, 1690, 1246, 1068, 1798, 1247, 1549, 1170, 2593, 1499, 1322, 1046, 1948, 1532, 1781, 1695, 1397, 1149, 1021, 1316, 1116, 1035, 1567, 1199, 1483, 1784, 1469, 1268, 2069, 1275, 1172, 1987, 1645, 1815, 1242, 1229, 1843, 1092, 1428, 1056, 2703, 1552, 1763, 1823, 2880, 1475, 1503, 1362, 1849, 1196, 2224, 2040, 2325, 1014, 2143, 1647, 1091, 1045, 1972, 1935, 1949, 1407, 1431, 1307, 1027, 1398, 1284, 1227, 1058, 2044, 1327, 1600, 1280, 1093, 2252, 2118, 1277, 1462, 1210, 1278, 1194, 1408, 1727, 1687, 1503, 2256, 1335, 1201, 3047, 1081, 1720, 1104, 1369, 1118, 1151, 1075, 1632, 1937, 2386, 1088, 1023, 1354, 1035, 1242, 1078, 1922, 1561, 1258, 1358, 1021, 1
# ...

# %%
text_splitter.create_documents([sample])
# Out:
# WARNING:langchain.text_splitter:Created a chunk of size 1332, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1050, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1109, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1216, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1344, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1235, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1051, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1222, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1340, which is longer than the specified 1000
# ...

# %%
from langchain.document_loaders import PyPDFLoader

loader = PyPDFLoader('/content/drive/MyDrive/Colab Notebooks/DS트랙 강의자료_LLM/이론/T-12-01-04_Mixed Precision.pdf')
pages = loader.load_and_split()

# %%
len(pages)
# Out:
# 13

# %%
print(pages[2].page_content)
# Out:
# MIXED PRECISION TRAINING
# How to represent a number in IEEE 754 floating point?
# Half precision FP16 0101110000011101
# 263.3 Single precision FP32 01000011100000111010011001100110
# Double precision FP64 0100000001110000011101001100110011001100110011001100110011001101sign (1 bit)
# exponent (5 bit)
# fraction (10 bit)
# sign (1 bit)
# exponent (8 bit)
# fraction (23 bit)
# sign (1 bit)
# exponent (11 bit)
# fraction (52 bit)-inf 0 inf
# 2−24−2−2465504 −65504

# %%
from langchain.text_splitter import CharacterTextSplitter

text_splitter = CharacterTextSplitter(
    separator='\n\n',
    chunk_size=1000,
    chunk_overlap=100,
    length_function=len,
)

# %%
texts = text_splitter.split_text(pages[2].page_content)
texts
# Out:
# ['MIXED PRECISION TRAINING\nHow to represent a number in IEEE 754 floating point?\nHalf precision FP16 0101110000011101\n263.3 Single precision FP32 01000011100000111010011001100110\nDouble precision FP64 0100000001110000011101001100110011001100110011001100110011001101sign (1 bit)\nexponent (5 bit)\nfraction (10 bit)\nsign (1 bit)\nexponent (8 bit)\nfraction (23 bit)\nsign (1 bit)\nexponent (11 bit)\nfraction (52 bit)-inf 0 inf\n2−24−2−2465504 −65504']

# %% [markdown]
# Recursive Text Splitter

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    # separator='\n\n',
    chunk_size=1000,
    chunk_overlap=200,
    length_function=len,
)
texts = text_splitter.create_documents([sample])
print(texts[0].page_content)
print('-'*100)
print(texts[1].page_content)
print('-'*100)
print(texts[2].page_content)
# Out:
# ﻿The Project Gutenberg eBook of The Complete Works of William Shakespeare
#
# This ebook is for the use of anyone anywhere in the United States and
# most other parts of the world at no cost and with almost no restrictions
# whatsoever. You may copy it, give it away or re-use it under the terms
# of the Project Gutenberg License included with this ebook or online
# at www.gutenberg.org. If you are not located in the United States,
# you will have to check the laws of the country where you are located
# before using this eBook.
#
# Title: The Complete Works of William Shakespeare
#
#
# Author: William Shakespeare
#
# Release date: January 1, 1994 [eBook #100]
#                 Most recently updated: January 18, 2024
#
# Language: English
#
#
#
# *** START OF THE PROJECT GUTENBERG EBOOK THE COMPLETE WORKS OF WILLIAM SHAKESPEARE ***
# ﻿The Complete Works of William Shakespeare
#
# by William Shakespeare
#
#
#
#
#                     Contents
# ...

# %%
char_list_over_1000 = []
char_list = []
for i in range(len(texts)):
    char_list.append(len(texts[i].page_content))
    if len(texts[i].page_content) > 1000:
        char_list.append(len(texts[i].page_content))
print(f'char_list_over_1000 = {char_list_over_1000}')
print(f'char_list = {char_list}')
# Out:
# char_list_over_1000 = []
# ...

# %% [markdown]
# Other Splitters

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter, Language

# %%
RecursiveCharacterTextSplitter.get_separators_for_language(Language.PYTHON)
# Out:
# ['\nclass ', '\ndef ', '\n\tdef ', '\n\n', '\n', ' ', '']

# %%
RecursiveCharacterTextSplitter.get_separators_for_language(Language.PYTHON)
python_code = '''
def hello_word():
    print('hello_word')

# Calls the function
hello_word()
'''
python_splitter = RecursiveCharacterTextSplitter.from_language(
    chunk_size=50,
    chunk_overlap=0,
    language=Language.PYTHON,
)
python_docs = python_splitter.create_documents([python_code])
python_docs
# Out:
# [Document(page_content="def hello_word():\n    print('hello_word')"),
#  Document(page_content='# Calls the function\nhello_word()')]

# %% [markdown]
# Token-Level Text Splitter

# %%
# !pip install -qqq cohere openai
# !pip install -qqq tiktoken
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.2/52.2 kB 1.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.7/226.7 kB 8.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 44.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.9/75.9 kB 9.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 9.0 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 9.8 MB/s eta 0:00:00

# %%
import tiktoken

tokenizer = tiktoken.get_encoding('cl100k_base')

def tiktoken_len(text):
    tokens = tokenizer.encode(text)
    return len(tokens)

tiktoken_len(texts[1].page_content)
# Out:
# 336

# %%
text_splitter=RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=0,
    length_function=tiktoken_len,
)
texts = text_splitter.split_text(sample)
texts[0]
# Out:
# '\ufeffThe Project Gutenberg eBook of The Complete Works of William Shakespeare\n    \nThis ebook is for the use of anyone anywhere in the United States and\nmost other parts of the world at no cost and with almost no restrictions\nwhatsoever. You may copy it, give it away or re-use it under the terms\nof the Project Gutenberg License included with this ebook or online\nat www.gutenberg.org. If you are not located in the United States,\nyou will have to check the laws of the country where you are located\nbefore using this eBook.\n\nTitle: The Complete Works of William Shakespeare\n\n\nAuthor: William Shakespeare\n\nRelease date: January 1, 1994 [eBook #100]\n                Most recently updated: January 18, 2024\n\nLanguage: English\n\n\n\n*** START OF THE PROJECT GUTENBERG EBOOK THE COMPLETE WORKS OF WILLIAM SHAKESPEARE ***\n\ufeffThe Complete Works of William Shakespeare\n\nby William Shakespeare\n\n\n\n\n                    Contents\n\n    THE SONNETS\n    ALL’S WELL THAT ENDS W
# ...

# %%
token_list = []
for i in range(len(texts)):
    token_list.append(tiktoken_len(texts[i]))
print(token_list)
# Out:
# [989, 913, 945, 908, 927, 944, 920, 948, 910, 918, 905, 879, 922, 901, 896, 939, 924, 943, 906, 934, 897, 895, 950, 934, 892, 948, 924, 899, 858, 958, 964, 944, 972, 916, 962, 968, 870, 941, 935, 696, 962, 961, 960, 833, 934, 912, 870, 954, 953, 930, 948, 915, 926, 950, 962, 967, 970, 899, 932, 947, 956, 966, 980, 952, 918, 926, 915, 940, 921, 898, 851, 929, 974, 918, 967, 927, 955, 968, 893, 954, 840, 933, 928, 943, 946, 896, 930, 958, 873, 936, 957, 777, 962, 937, 952, 976, 965, 922, 851, 933, 887, 953, 907, 952, 965, 915, 961, 940, 968, 959, 920, 809, 960, 955, 972, 939, 942, 960, 926, 813, 968, 971, 952, 958, 986, 975, 903, 928, 947, 950, 958, 960, 965, 958, 981, 948, 964, 966, 951, 909, 965, 961, 920, 923, 964, 968, 973, 957, 961, 914, 948, 965, 943, 948, 966, 939, 959, 812, 971, 964, 972, 951, 948, 959, 889, 967, 936, 927, 779, 798, 979, 942, 915, 929, 913, 948, 914, 961, 946, 948, 952, 963, 943, 922, 878, 953, 935, 972, 937, 942, 964, 977, 965, 937, 957, 966, 946, 959, 938, 91
# ...

# %% [markdown]
# # Text Embedding

# %% [markdown]
# OpenAI Embeddings

# %%
# !pip install -qqq openai langchain pypdf tiktoken

# %%
from langchain.embeddings import OpenAIEmbeddings
from google.colab import userdata

embeddings_model = OpenAIEmbeddings(openai_api_key=userdata.get('OpenAI_API'))
embeddings = embeddings_model.embed_documents(
    ['안녕하세요',
     '제 이름은 홍길동입니다.',
     '이름이 무엇인가요?',
     '랭체인은 유용합니다.',
     'Hello World!']
)
len(embeddings), len(embeddings[0])
# Out:
# (5, 1536)

# %%
embedded_query_q = embeddings_model.embed_query('이 대화에서 언급된 이름은 무엇입니까?')
embedded_query_a = embeddings_model.embed_query('이 대화에서 언급된 이름은 홍길동입니다.')
len(embedded_query_q), len(embedded_query_a)
# Out:
# (1536, 1536)

# %%
import numpy as np
def cos_sim(A, B):
    return np.dot(A,B)/(np.linalg.norm(A)*np.linalg.norm(B))

# %%
print(cos_sim(embedded_query_q, embedded_query_a))
print(cos_sim(embedded_query_q, embeddings[1]))
print(cos_sim(embedded_query_q, embeddings[3]))
# Out:
# 0.9012151416840555
# 0.8499725111377555
# 0.7753900276853167

# %% [markdown]
# HuggingFace Embeddings

# %%
# !pip install -qqq sentence_transformers
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.8/132.8 kB 2.9 MB/s eta 0:00:00

# %%
from langchain.embeddings import HuggingFaceBgeEmbeddings
model_name = 'BAAI/bge-small-en'
model_kwargs={'device':'cpu'}
encode_kwargs={'normalize_embeddings':True}
hf = HuggingFaceBgeEmbeddings(
    model_name=model_name,
    model_kwargs=model_kwargs,
    encode_kwargs=encode_kwargs
    )
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/90.8k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/684 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/133M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/366 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
embeddings = hf.embed_documents(
    ['today is monday',
     'weather is nice today',
     'what is the problem?',
     'langchain is useful',
     'Hello World!',
     'my name is Morris'
     ]
)

# %%
BGE_query_q = 'Hello? who is this?'
BGE_query_a = 'Hello World!'
BGE_query_q_emb = hf.embed_query(BGE_query_q)
BGE_query_a_emb = hf.embed_query(BGE_query_a)
print(cos_sim(BGE_query_q_emb, BGE_query_a_emb))
print(cos_sim(BGE_query_q_emb, embeddings[0]))
print(cos_sim(BGE_query_q_emb, embeddings[1]))
print(cos_sim(BGE_query_q_emb, embeddings[5]))
# Out:
# 0.8596507049981911
# 0.7752296895541576
# 0.7469068511786857
# 0.792870425931663

# %%
sentences =[
    '안녕하세요',
    '제 이름은 홍길동입니다.',
    '이름이 무엇인가요?',
    '랭체인은 유용합니다.',
    '홍길동 아버지의 이름은 홍상직입니다.',

    ]
ko_embeddings = hf.embed_documents(sentences)

# %%
q = '홍길동은 아버지를 아버지라 부르지 못하였습니다. 홍길동 아버지의 이름은 무엇입니까?'
a = '홍길동의 아버지는 엄했습니다.'
BGE_query_q_2 = hf.embed_query(q)
BGE_query_a_2 = hf.embed_query(a)

print(f'질문 : {q} \n', '-'*100)
print(f'{a} \t\t 문장 유사도: ', round(cos_sim(BGE_query_q_2, BGE_query_a_2), 2))
print(sentences[1] + '\t\t 문장 유사도: ', round(cos_sim(BGE_query_q_2, ko_embeddings[1]), 2))
print(sentences[3] + '\t\t\t 문장 유사도: ', round(cos_sim(BGE_query_q_2, ko_embeddings[3]), 2))
print(sentences[4] + '\t 문장 유사도: ', round(cos_sim(BGE_query_q_2, ko_embeddings[4]), 2))
# Out:
# 질문 : 홍길동은 아버지를 아버지라 부르지 못하였습니다. 홍길동 아버지의 이름은 무엇입니까?
#  ----------------------------------------------------------------------------------------------------
# 홍길동의 아버지는 엄했습니다. 		 문장 유사도:  0.95
# 제 이름은 홍길동입니다.		 문장 유사도:  0.88
# 랭체인은 유용합니다.			 문장 유사도:  0.85
# 홍길동 아버지의 이름은 홍상직입니다.	 문장 유사도:  0.92

# %%
from langchain.embeddings import HuggingFaceEmbeddings

model_name = 'jhgan/ko-sbert-nli'
model_kwargs={'device':'cpu'}
encode_kwargs={'normalize_embeddings':True}
ko = HuggingFaceEmbeddings(
    model_name=model_name,
    model_kwargs=model_kwargs,
    encode_kwargs=encode_kwargs
    )
# Out:
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/123 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/4.46k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/620 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/443M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/538 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/248k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/495k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
ko_embeddings = ko.embed_documents(sentences)

ko_query_q = ko.embed_query(q)
ko_query_a = ko.embed_query(a)

print(f'질문 : {q} \n', '-'*100)
print(f'{a} \t\t 문장 유사도: ', round(cos_sim(ko_query_q, ko_query_a), 2))
print(sentences[1] + '\t\t 문장 유사도: ', round(cos_sim(ko_query_q, ko_embeddings[1]), 2))
print(sentences[3] + '\t\t\t 문장 유사도: ', round(cos_sim(ko_query_q, ko_embeddings[3]), 2))
print(sentences[4] + '\t 문장 유사도: ', round(cos_sim(ko_query_q, ko_embeddings[4]), 2))
# Out:
# 질문 : 홍길동은 아버지를 아버지라 부르지 못하였습니다. 홍길동 아버지의 이름은 무엇입니까?
#  ----------------------------------------------------------------------------------------------------
# 홍길동의 아버지는 엄했습니다. 		 문장 유사도:  0.47
# 제 이름은 홍길동입니다.		 문장 유사도:  0.54
# 랭체인은 유용합니다.			 문장 유사도:  0.03
# 홍길동 아버지의 이름은 홍상직입니다.	 문장 유사도:  0.61

# %% [markdown]
# ## Vector Store

# %%
# !pip install -qqq langchain chromadb tiktoken transformers sentence_transformers
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 509.0/509.0 kB 5.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 9.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.1/41.1 kB 4.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 20.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.9/57.9 kB 6.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.6/105.6 kB 11.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 7.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 698.9/698.9 kB 22.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 27.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.6/67.6 kB 7.1 MB/s eta 0:00:00
# ...

# %%
import tiktoken
from langchain.text_splitter import RecursiveCharacterTextSplitter
tokenizer = tiktoken.get_encoding('cl100k_base')

def tiktoken_len(text):
    tokens=tokenizer.encode(text)
    return len(tokens)

# %%
from langchain.embeddings.sentence_transformer import SentenceTransformerEmbeddings
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores import Chroma
from langchain.document_loaders import PyPDFLoader

# %%
from langchain.embeddings import HuggingFaceEmbeddings

loader = PyPDFLoader('/content/drive/MyDrive/Colab Notebooks/LangChain/[이슈리포트 2022-2호] 혁신성장 정책금융 동향.pdf')
pages = loader.load_and_split()
text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=0, length_function=tiktoken_len)
docs = text_splitter.split_documents(pages)

model_name = 'jhgan/ko-sbert-nli'
model_kwargs={'device':'cpu'}
encode_kwargs={'normalize_embeddings':True}
hfs = HuggingFaceEmbeddings(
    model_name=model_name,
    model_kwargs=model_kwargs,
    encode_kwargs=encode_kwargs
    )

# %%
from langchain.vectorstores import Chroma
from chromadb.errors import InvalidDimensionException

try:
    db = Chroma.from_documents(docs, hfs)
except InvalidDimensionException:
    Chroma().delete_collection()
    db = Chroma.from_documents(docs, hfs)

query = '6대 먹거리 산업은?'
docs = db.similarity_search(query)
print(docs[0].page_content)
# Out:
# -컴퓨팅 기술을 활용한 다양한 사업화가 활발히 진행되고 있어 혁신성장 정책금융 공급 규모가 매년
# 약 100% 수준으로 증가하고 있으며 , 새정부의 ‘미래 먹거리산업 신성장 전략추진*’에 따라 인공
# 지능 관련 기술로의 금융지원이 늘어날 것으로 전망됨
#        * 에너지 , 방산, 우주항공 , 인공지능 (AI), 바이오 , 탄소중립 대응, 스마트농업을 차세대 6대 먹거리 산업으로 선정

# %%
tiktoken_len(docs[0].page_content)
# Out:
# 229

# %%
db2 = Chroma.from_documents(docs, hfs, persist_directory='./chroma_db')
docs = db2.similarity_search(query)
db3 = Chroma(persist_directory='./chroma_db', embedding_function=hfs)
docs = db3.similarity_search(query)
print(docs[0].page_content)
# Out:
# -컴퓨팅 기술을 활용한 다양한 사업화가 활발히 진행되고 있어 혁신성장 정책금융 공급 규모가 매년
# 약 100% 수준으로 증가하고 있으며 , 새정부의 ‘미래 먹거리산업 신성장 전략추진*’에 따라 인공
# 지능 관련 기술로의 금융지원이 늘어날 것으로 전망됨
#        * 에너지 , 방산, 우주항공 , 인공지능 (AI), 바이오 , 탄소중립 대응, 스마트농업을 차세대 6대 먹거리 산업으로 선정

# %%
docs = db3.similarity_search_with_relevance_scores(query, k=3)
print(f'가장 유사한 문서 \n\n {docs[0][0].page_content}\n\n')
print(f'문서 유사도: \n {docs[0][1]}')
# Out:
# 가장 유사한 문서
#
#  -컴퓨팅 기술을 활용한 다양한 사업화가 활발히 진행되고 있어 혁신성장 정책금융 공급 규모가 매년
# 약 100% 수준으로 증가하고 있으며 , 새정부의 ‘미래 먹거리산업 신성장 전략추진*’에 따라 인공
# 지능 관련 기술로의 금융지원이 늘어날 것으로 전망됨
#        * 에너지 , 방산, 우주항공 , 인공지능 (AI), 바이오 , 탄소중립 대응, 스마트농업을 차세대 6대 먹거리 산업으로 선정
#
#
# 문서 유사도:
#  0.2549497432307306

# %% [markdown]
# ## FAISS

# %%
# !pip install -qqq faiss-cpu
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 28.2 MB/s eta 0:00:00

# %%
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.text_splitter import CharacterTextSplitter
from langchain.vectorstores import FAISS
from langchain.document_loaders import TextLoader

# %%
from langchain.embeddings import HuggingFaceEmbeddings

docs = text_splitter.split_documents(pages)
model_name = 'jhgan/ko-sbert-nli'
model_kwargs={'device':'cpu'}
encode_kwargs={'normalize_embeddings':True}
ko = HuggingFaceEmbeddings(
    model_name=model_name,
    model_kwargs=model_kwargs,
    encode_kwargs=encode_kwargs
    )

# %%
db = FAISS.from_documents(docs, ko)
query = '인공지능 산업구조는 어떻게 구성되어있어?'
docs = db.similarity_search(query)
print(docs[0].page_content)
# Out:
# | 10 | CIS이슈리포트 2022-2 호 ▶인공지능 산업의 value chain 은 ‘AI 플랫폼 공급업체 → AI 어플리케이션 개발 → AI 응용솔루션
# 개발 → 이용자 ’로 구성되며 , 동 산업은 ①성장기 산업, ②대체재로부터의 위협이 낮은 산업, ③기
# 술집약적 산업 등의 특징을 가짐
# ￮알고리즘 , 하드웨어 기술개발과 응용솔루션 서비스 상용화가 활발히 진행 중인 성장기 산업이며 ,
# 수요 기업의 요구사항에 따라 운영플랫폼을 선택할 수 있는 구매자의 교섭력이 높은 산업임
# ￮직접적인 대체 기술이 없어 대체재로부터 위협이 낮은 편이며 , 알고리즘의 동작원리를 이해하고 맞
# 춤형 서비스를 지원하기 위한 솔루션 개발 능력이 뒷받침 되어야 하는 기술집약적 산업임
# ▶시장조사전문기관 BCC research 에 따르면 세계 인공지능 시장규모는 2020년 398.4 억 달러에서

# %%
docs_and_scores = db.similarity_search_with_score(query)
docs_and_scores
# Out:
# [(Document(page_content='| 10 | CIS이슈리포트 2022-2 호 ▶인공지능 산업의 value chain 은 ‘AI 플랫폼 공급업체 → AI 어플리케이션 개발 → AI 응용솔루션  \n개발 → 이용자 ’로 구성되며 , 동 산업은 ①성장기 산업, ②대체재로부터의 위협이 낮은 산업, ③기\n술집약적 산업 등의 특징을 가짐\n￮알고리즘 , 하드웨어 기술개발과 응용솔루션 서비스 상용화가 활발히 진행 중인 성장기 산업이며 , \n수요 기업의 요구사항에 따라 운영플랫폼을 선택할 수 있는 구매자의 교섭력이 높은 산업임\n￮직접적인 대체 기술이 없어 대체재로부터 위협이 낮은 편이며 , 알고리즘의 동작원리를 이해하고 맞\n춤형 서비스를 지원하기 위한 솔루션 개발 능력이 뒷받침 되어야 하는 기술집약적 산업임\n▶시장조사전문기관 BCC research 에 따르면 세계 인공지능 시장규모는 2020년 398.4 억 달러에서', metadata={'source': '/content/drive/MyDrive/Colab Notebooks/LangChain/[이슈리포트 2022-2호] 혁신성장 정책금융 동향.pdf', 'page': 9}),
#   0.69344294),
# ...

# %%
db.save_local('faiss_index')

# %%
new_db = FAISS.load_local('faiss_index', ko)
docs = new_db.similarity_search_with_relevance_scores(query)
print(f'질문 : {query} \n')
for i in range(len(docs)):
    print(f'{i+1}번째 질문과 유사도 : {round(docs[i][1], 2)} \n')
    print('-'*100)
    print(docs[i][0].page_content)
    print('-'*100)
    print('\n')
    print(docs[i][0].metadata)
    print('-'*100)
# Out:
# 질문 : 인공지능 산업구조는 어떻게 구성되어있어?
#
# 1번째 질문과 유사도 : 0.51
#
# ----------------------------------------------------------------------------------------------------
# | 10 | CIS이슈리포트 2022-2 호 ▶인공지능 산업의 value chain 은 ‘AI 플랫폼 공급업체 → AI 어플리케이션 개발 → AI 응용솔루션
# 개발 → 이용자 ’로 구성되며 , 동 산업은 ①성장기 산업, ②대체재로부터의 위협이 낮은 산업, ③기
# 술집약적 산업 등의 특징을 가짐
# ￮알고리즘 , 하드웨어 기술개발과 응용솔루션 서비스 상용화가 활발히 진행 중인 성장기 산업이며 ,
# 수요 기업의 요구사항에 따라 운영플랫폼을 선택할 수 있는 구매자의 교섭력이 높은 산업임
# ￮직접적인 대체 기술이 없어 대체재로부터 위협이 낮은 편이며 , 알고리즘의 동작원리를 이해하고 맞
# 춤형 서비스를 지원하기 위한 솔루션 개발 능력이 뒷받침 되어야 하는 기술집약적 산업임
# ▶시장조사전문기관 BCC research 에 따르면 세계 인공지능 시장규모는 2020년 398.4 억 달러에서
# ----------------------------------------------------------------------------------------------------
#
#
# {'source': '/content/drive/MyDrive/Colab Notebooks/LangChain/[이슈리포트 2022-2호] 혁신성장 정책금융 동향.pdf', 'page': 9}
# ----------------------------------------------------------------------------------------------------
# 2번째 질문과 유사도 : 0.48
#
# ...

# %%
query = '인공지능 산업구조는 어떻게 되어있어?'
docs = new_db.max_marginal_relevance_search(query, k=3, fetch_k=10, lambda_mult=0.3)
print(f'질문 : {query} \n')
for i in range(len(docs)):
    print(f'{i+1}번째 유사 문서')
    print('-'*100)
    print(docs[i].page_content)
    print('-'*100)
    print('\n')
    print(docs[i].metadata)
    print('-'*100)
# Out:
# 질문 : 인공지능 산업구조는 어떻게 되어있어?
#
# 1번째 유사 문서
# ----------------------------------------------------------------------------------------------------
# | 10 | CIS이슈리포트 2022-2 호 ▶인공지능 산업의 value chain 은 ‘AI 플랫폼 공급업체 → AI 어플리케이션 개발 → AI 응용솔루션
# 개발 → 이용자 ’로 구성되며 , 동 산업은 ①성장기 산업, ②대체재로부터의 위협이 낮은 산업, ③기
# 술집약적 산업 등의 특징을 가짐
# ￮알고리즘 , 하드웨어 기술개발과 응용솔루션 서비스 상용화가 활발히 진행 중인 성장기 산업이며 ,
# 수요 기업의 요구사항에 따라 운영플랫폼을 선택할 수 있는 구매자의 교섭력이 높은 산업임
# ￮직접적인 대체 기술이 없어 대체재로부터 위협이 낮은 편이며 , 알고리즘의 동작원리를 이해하고 맞
# 춤형 서비스를 지원하기 위한 솔루션 개발 능력이 뒷받침 되어야 하는 기술집약적 산업임
# ▶시장조사전문기관 BCC research 에 따르면 세계 인공지능 시장규모는 2020년 398.4 억 달러에서
# ----------------------------------------------------------------------------------------------------
#
#
# {'source': '/content/drive/MyDrive/Colab Notebooks/LangChain/[이슈리포트 2022-2호] 혁신성장 정책금융 동향.pdf', 'page': 9}
# ----------------------------------------------------------------------------------------------------
# 2번째 유사 문서
# ...

# %%
# !pip install -qqq chromadb tiktoken transformers sentence_transformers openai langchain pypdf

# %%
import os
import openai
from google.colab import userdata
os.environ["OPENAI_API_KEY"]=userdata.get('OpenAI_API')

# %%
tokenizer=tiktoken.get_encoding('cl100k_base')
def tiktoken_len(text):
    tokens = tokenizer.encode(text)
    return len(tokens)

# %%
from langchain.chains import RetrievalQA
from langchain.chat_models import ChatOpenAI
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores import Chroma
from langchain.document_loaders import PyPDFLoader

# %%
loader = PyPDFLoader('/content/drive/MyDrive/Colab Notebooks/LangChain/[이슈리포트 2022-2호] 혁신성장 정책금융 동향.pdf')
pages = loader.load_and_split()
text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50, length_function=tiktoken_len)
texts = text_splitter.split_documents(pages)

from langchain.embeddings import HuggingFaceEmbeddings

model_name = 'jhgan/ko-sbert-nli'
model_kwargs={'device':'cpu'}
encode_kwargs={'normalize_embeddings':True}

hf = HuggingFaceEmbeddings(
    model_name=model_name,
    model_kwargs=model_kwargs,
    encode_kwargs=encode_kwargs
    )


docsearch = Chroma.from_documents(texts, hf)

# %%
from langchain.callbacks.streaming_stdout import StreamingStdOutCallbackHandler

openai = ChatOpenAI(model_name='gpt-3.5-turbo',
                    streaming=True, callbacks=[StreamingStdOutCallbackHandler()],
                    temperature=0)

qa = RetrievalQA.from_chain_type(
    llm = openai,
    chain_type='stuff',
    retriever=docsearch.as_retriever(
        search_type='mmr',
        search_kwargs={'k':3, 'fetch_k':10}
    ),
    return_source_documents=True
    )
query = '혁신성장 정책금융에 대해서 설명해줘'
result = qa(query)
# Out:
# 혁신성장 정책금융은 기업의 성장을 지원하기 위해 정부나 정책금융기관이 제공하는 금융 지원 제도입니다. 이 제도는 건강한 혁신산업 생태계를 조성하고, 기업의 성장에 필요한 자금을 지원하기 위해 시행되고 있습니다.
#
# 혁신성장 정책금융기관은 혁신성장에 대한 정의를 구체화한 정책금융 가이드라인에 따라 혁신성장 산업육성을 위한 정책금융 업무를 추진하고 있습니다. 이 가이드라인은 혁신성장 기업을 발굴하고 금융지원하기 위해 활용되며, 9대 테마, 46개 분야, 296개 품목으로 구성되어 있습니다.
#
# 혁신성장 정책금융 제도는 미래 혁신성장 분야의 글로벌 경쟁력 확보를 위해 지속적으로 금융지원을 추진하고 있습니다. 정책금융기관의 혁신성장 분야 정책금융 공급규모는 매년 증가하고 있으며, 2017년 240,787억 원에서 연평균 37.2% 증가하여 2021년에는 854,338억 원에 이르는 수준으로 확대되었습니다.
#
# 또한, 혁신성장 정책금융은 미래 성장성이 높지만 단기 수익 창출이 어려운 산업의 지원을 강화하기 위해 정책금융뿐만 아니라 민관주도의 역동적인 금융으로 영역을 확대할 필요가 있습니다.
#
# 컴퓨팅 기술을 활용한 다양한 사업화가 활발히 진행되고 있어 혁신성장 정책금융 공급규모가 매년 약 100% 수준으로 증가하고 있습니다. 또한, 새로운 정부의 '미래 먹거리산업 신성장 전략추진'에 따라 인공지능 관련 기술로의 금융지원이 더욱 늘어날 것으로 전망됩니다.

# %%
result.keys()
# Out:
# dict_keys(['query', 'result', 'source_documents'])

# %%
result['result']
# Out:
# "혁신성장 정책금융은 기업의 성장을 지원하기 위해 정부나 정책금융기관이 제공하는 금융 지원 제도입니다. 이 제도는 건강한 혁신산업 생태계를 조성하고, 기업의 성장에 필요한 자금을 지원하기 위해 시행되고 있습니다.\n\n혁신성장 정책금융기관은 혁신성장에 대한 정의를 구체화한 정책금융 가이드라인에 따라 혁신성장 산업육성을 위한 정책금융 업무를 추진하고 있습니다. 이 가이드라인은 혁신성장 기업을 발굴하고 금융지원하기 위해 활용되며, 9대 테마, 46개 분야, 296개 품목으로 구성되어 있습니다.\n\n혁신성장 정책금융 제도는 미래 혁신성장 분야의 글로벌 경쟁력 확보를 위해 지속적으로 금융지원을 추진하고 있습니다. 정책금융기관의 혁신성장 분야 정책금융 공급규모는 매년 증가하고 있으며, 2017년 240,787억 원에서 연평균 37.2% 증가하여 2021년에는 854,338억 원에 이르는 수준으로 확대되었습니다.\n\n또한, 혁신성장 정책금융은 미래 성장성이 높지만 단기 수익 창출이 어려운 산업의 지원을 강화하기 위해 정책금융뿐만 아니라 민관주도의 역동적인 금융으로 영역을 확대할 필요가 있습니다.\n\n컴퓨팅 기술을 활용한 다양한 사업화가 활발히 진행되고 있어 혁신성장 정책금융 공급규모가 매년 약 100% 수준으로 증가하고 있습니다. 또한, 새로운 정부의 '미래 먹거리산업 신성장 전략추진'에 따라 인공지능 관련 기술로의 금융지원이 더욱 늘어날 것으로 전망됩니다."

# %%
result['source_documents'][0].metadata
# Out:
# {'page': 2,
#  'source': '/content/drive/MyDrive/Colab Notebooks/LangChain/[이슈리포트 2022-2호] 혁신성장 정책금융 동향.pdf'}
